# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df = pd.read_csv("../dataset_raw/titanic.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: partially initialized module 'pandas' from 'C:\Users\anggun\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\__init__.py' has no attribute '_pandas_datetime_CAPI' (most likely due to a circular import)
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2
#       3 df = pd.read_csv("../dataset_raw/titanic.csv")
#       4 df.head()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\__init__.py:58
#      55 # let init-time option registration happen
#      56 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 58 from pandas.core.api import (
#      59     # dtype
# ...

# %%
import os

print("Folder aktif:")
print(os.getcwd())

print("\nIsi folder:")
print(os.listdir())
# Out:
# Folder aktif:
# C:\Users\anggun\Documents\GitHub\Eksperimen_SML_AnggunPuspita\preprocessing
#
# Isi folder:
# ['data_preprocessing', 'Eksperimen_AnggunPuspita.ipynb']

# %%
import os

print(os.listdir(".."))
# Out:
# ['.git', '.gitignore', '.idea', 'dataset_raw', 'preprocessing', 'README.md']

# %%
print(os.listdir("../dataset_raw/dataset_raw"))
# Out:
# ['titanic.csv']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(data=df, x="Survived")
plt.show()

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])

df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df = df.drop(["PassengerId", "Name", "Ticket", "Cabin"], axis=1)

df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
df = pd.get_dummies(df, columns=["Sex", "Embarked"], drop_first=True)

df.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_Q  \
# 0         0       3  22.0      1      0   7.2500      True       False
# 1         1       1  38.0      1      0  71.2833     False       False
# 2         1       3  26.0      0      0   7.9250     False       False
# 3         1       1  35.0      1      0  53.1000     False       False
# 4         0       3  35.0      0      0   8.0500      True       False
#
#    Embarked_S
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True

# %%
df.to_csv("data_preprocessing/titanic_preprocessed.csv", index=False)

print("Dataset preprocessing berhasil disimpan")
# Out:
# Dataset preprocessing berhasil disimpan

# %%
import os

print(os.listdir("data_preprocessing"))
# Out:
# ['titanic_preprocessed.csv']
